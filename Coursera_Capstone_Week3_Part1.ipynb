# %% [markdown]
# # Obtain the data that is in the table of postal codes and to transform the data into a pandas dataframe

# %% [markdown]
# ## Ziyang Liu

# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)

import json # library to handle JSON files

# !conda install -c conda-forge geopy --yes
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from bs4 import BeautifulSoup # library to parse HTML and XML documents

from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

# !conda install -c conda-forge folium=0.5.0 --yes
import folium # map rendering library

print("Libraries imported.")
# Out:
# ...
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\software\Anaconda
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     conda-4.8.3                |   py37hc8dfbb8_1         3.1 MB  conda-forge
#     geographiclib-1.50         |             py_0          34 KB  conda-forge
#     geopy-2.0.0                |     pyh9f0ad1d_0          63 KB  conda-forge
#     python_abi-3.7             |          1_cp37m           4 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         3.2 MB
#
# The following NEW packages will be INSTALLED:
#
#   geographiclib      conda-forge/noarch::geographiclib-1.50-py_0
#   geopy              conda-forge/noarch::geopy-2.0.0-pyh9f0ad1d_0
# ...

# %%
my_url = 'https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'
my_data = requests.get(myurl) # send request
my_data.status_code
# Out:
# 200

# %%
df_1 = pd.read_html(my_url)[0] # convert data into dataframe
df_1.shape
# Out:
# (180, 3)

# %%
df_1.head()
# Out:
#   Postal Code           Borough              Neighbourhood
# 0         M1A      Not assigned               Not assigned
# 1         M2A      Not assigned               Not assigned
# 2         M3A        North York                  Parkwoods
# 3         M4A        North York           Victoria Village
# 4         M5A  Downtown Toronto  Regent Park, Harbourfront

# %%
# Only process the cells that have an assigned borough. Ignore cells with a borough that is Not assigned
df_2 = df_1[df_1.Borough != 'Not assigned'].reset_index(drop=True)
df_2.head()
# Out:
#   Postal Code           Borough                                Neighbourhood
# 0         M3A        North York                                    Parkwoods
# 1         M4A        North York                             Victoria Village
# 2         M5A  Downtown Toronto                    Regent Park, Harbourfront
# 3         M6A        North York             Lawrence Manor, Lawrence Heights
# 4         M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government

# %%
print(df_2.shape)
df_2.groupby(["Postal Code", "Borough"]).count() # Neighbourhoods have already been combined
# Out:
# (103, 3)
#                               Neighbourhood
# Postal Code Borough
# M1B         Scarborough                   1
# M1C         Scarborough                   1
# M1E         Scarborough                   1
# M1G         Scarborough                   1
# M1H         Scarborough                   1
# M1J         Scarborough                   1
# M1K         Scarborough                   1
# M1L         Scarborough                   1
# M1M         Scarborough                   1
# M1N         Scarborough                   1
# M1P         Scarborough                   1
# M1R         Scarborough                   1
# M1S         Scarborough                   1
# M1T         Scarborough                   1
# M1V         Scarborough                   1
# M1W         Scarborough                   1
# M1X         Scarborough                   1
# M2H         North York                    1
# M2J         North York                    1
# M2K         North York                    1
# ...

# %%
df_2[df_2['Neighbourhood']=='Not assigned'] # No non-assigned Neighbourhood
# Out:
# Empty DataFrame
# Columns: [Postal Code, Borough, Neighbourhood]
# Index: []

# %%
df_2.shape
# Out:
# (103, 3)

# %% [markdown]
# ### End of part 1
